# %% [markdown]
# ## Agent-Based Modeling
# ### What Is It? What's It For?

# %% [markdown]
# This is an introduction to Agent-Based Modeling (ABM). ABM is a type of computer programming with applications to physics, chemistry, biology, epidemiology, weather forecasting, forestry, sociology, economics, business, and even film making. But to understand what makes it different from other modeling, we need a little background.

# %% [markdown]
# ### What Is a Model?
#
# A model is a construction that "resembles" something we want to investigate, and which, by manipulation of the construct, we hope to learn about the subject we are investigating.

# %% [markdown]
# ### Three Types of Modeling

# %% [markdown]
# #### Simple Orders

# %% [markdown]
# The first successes of mathematical modeling of reality were in describing *simple orders*. A classic expression of a simple order is Newton's second law of motion, *F* = *ma*: it relates one quantity to only two others, in a very straightforward manner. Similar examples are models for springs, and pendulums, and heat diffusion. Models of simple orders usually take the form of *differential equations*. These types of models were developed extensively in the 18th and 19th centuries, and are still very important today.
#
# <div align="center">
# <figure>
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/f/fc/Hookes-law-springs.png/440px-Hookes-law-springs.png" width="25%">
#     <figcaption>
#         <i>Hooke's Law is a model of the simple order of an isolated spring.</i>
#     </figcaption>
# </figure>
# </div>
# <br/>
# <div align="center">
# <figure>
# <img
# src="https://upload.wikimedia.org/wikipedia/commons/f/f2/Orbit2.gif" width="25%">
#        <figcaption>
#         <i>A simple order: planetary orbits.</i>
#     </figcaption>
# </figure>
# </div>

# %% [markdown]
# #### Disorder

# %% [markdown]
# The second class of phenomena to be successfully modeled were *random* systems:
#
# "Whereas ordinary mechanics only considers the behaviour of a single state, statistical mechanics introduces the statistical ensemble, which is a large collection of virtual, independent copies of the system in various states. The statistical ensemble is a probability distribution over all possible states of the system." -- *Wikipedia*
#
# The study of such systems was conducted by the use of *statistical models*. Examples of phenomena successfully modeled in this way includes thermodynamical systems, gas diffusion, Brownian motion, the evolution of a quantum wave function, height and weight distributions in a population, and games of chance.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/c/c2/Brownian_motion_large.gif" width="25%">
#
# <div align="center">*Brownian motion: gas molecules producing random motion of a dust particle.*</div>
#
# In the mid-twentieth century, many scientists believed that these two types of models were all that were needed to capture all of reality: if some phenomenon could not be captured exactly by a simple model, then it must be random, and could be described by statistical analysis. But this view was soon to collapse, as, from multiple fields, researchers discovered...

# %% [markdown]
# #### Complex orders

# %% [markdown]
# The discovery of complex orders had been hinted at in work on the three-body problem: Newton had "solved" the problem of the planet's orbits by assuming that only the sun influenced their orbits, which is a good approximation. But once another planet was allowed to sneak into the system, the possible behavior became far more complex:
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/1/11/3bodyproblem.gif" width="74%">
#
# Well, at least for our solar system, these complexities could (mostly) be ignored. But for other systems this was not the case: as researchers looked into "far-from-equilibrium" systems like our weather, or chaotic fluid dynamics, or the behavior of asset markets, they found that these exhibited patterns that could not be captured by models of simple orders, nor models of pure randomness. They were discovering the existence of *complex orders*.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/6/6a/LogisticTopMixing1-6.gif/440px-LogisticTopMixing1-6.gif" width="25%">
#
# The behavior of these orders could not be captured by analysis of a differential equation, nor by statistical procedures. Instead, in general, one creates a model based on some (seemingly) simple rules, and then *runs the model*, and only by doing so does one discover what the system does.
#
# A milestone along this path was the discovery, by the mathematician Benoit Mandelbrot, of the *Mandelbrot set*. Mandelbrot took the "simple" equation,
#
# *f*<sub>*c*</sub>(*z*) = *z*<sup>2</sup> + *c*
#
# where *z* and *c* are complex numbers, and *iterated* it (feeding the result of one iteration into the next), with *z* at the start equal to 0, for *c* near the origin, and found that this seemingly simple equation produced fantastically complex results. In a *simple order*, small differences in the initial value of *c* ought to produce small differences in the final outcome. But Mandelbrot discovered that *extremely* small differences in the initial value of *c* could produce wildly divergent outcomes: this is a characteristic of complex systems: small differences in initial values can produce very big differences in the development of the system. If we color each point *c* by how fast the above equation moves away from the origin, we get a result like:
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/2/21/Mandel_zoom_00_mandelbrot_set.jpg/644px-Mandel_zoom_00_mandelbrot_set.jpg" width="25%">
# <div align="center">*The Mandelbrot set*</div>

# %%
from IPython.display import HTML

HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/pCpLWbHVNhk" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')

# %% [markdown]
# Similar phenomena were discovered in many fields... see the list of applications of ABMs above!... and a new field was opened to science: the study of *complex orders*. In general, we cannot either "solve" a problem in such an order by solving a differential equation, as we can for simple orders, or by purely statistical analysis, as we can for random phenomena. Instead, we must specify the rules the parts of the system must follow, and then we must *run the system*, most often on a computer, and see what *emerges*. (Another name for this field of study is *emergent phenomena*.)
#
# One of the important tools in exploring this (relatively) new field of complex orders has been *agent-based models*. In such models, instead of trying to find a "top-down" equation that we can solve, and therefore say exactly what the model predicts at time *t*, we instead create a number of *agents*, which we program to follow some rules of behavior, and then set those agents "loose" in an "environment" (our model), and allow them to interact. Such models are also sometimes called *cellular automata*.
#
# An early example of such a model was John Conway's *game of life*, where each "cell" on a grid evolved according to a simple rule, based on the state of its neighbors. Although the rules were simple, the "game" could produce very complex patterns:
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/e/e5/Gospers_glider_gun.gif" width="33%">
# <div align="center">*A "glider" in the game of life*</div>
#
# The pattern produced is clearly not "random," but it also could not be predicted by any "top-down" equation attempting to model the system. The system needs to be *run* in order to see what patterns *emerge*.

# %% [markdown]
# ## Thomas Schelling: A Career of Agent-Based Models
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/6/63/Thomas_Schelling.jpg" width="16%">
#
# A puzzle: where should you meet someone in NYC, if you can't communicate, and you are only told, "You will win a huge prize if you and X can find each other in New York sometime on Feb. 27"?
#
# There is a "right" place and time!
#
# .
#
# .
#
# .
#
# .
#
# .
#
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/4/40/USA-NYC-Grand_Central_Terminal_Clock.jpg/298px-USA-NYC-Grand_Central_Terminal_Clock.jpg">
#
# That clock, and noon, are "focal points."
#
#
# Some of his models:
#
# - The failed volleyball game
# - Auditorium story
# - Rubbernecking
# - Height
# - Segregation
#
# Pick up his book [*Micromotives and Macrobehavior*](https://en.wikipedia.org/wiki/Thomas_Schelling#Micromotives_and_Macrobehavior_(1978)) if this interests you!

# %% [markdown]
# ### Applications of Agent-Based Modeling

# %% [markdown]
# An early area in which ABMs were successfully applied was that of *flocking* or *schooling*. Birds form "flocks," and fish "schools," and these groups exhibit behavior that clearly is not random, but also cannot be described by any simple equation. For instance, check out this school of fish:

# %%
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/15B8qN9dre4" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')

# %% [markdown]
# Note that there is no fish "choreographer": the school must emerge "bottom-up" from the behavior of individual fish.
#
# Using ABMs, researchers discovered that they could create agents that followed simple rules, and yet produced this sort of complex phenomena, like "boids":

# %%
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/QbUPfMXXQIY" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')

# %% [markdown]
# ABM models have also been useful in many other fields, as noted above. Perhaps of particular interest is their application, over the past two decades, in film making. A common difficulty faced by film makers trying to shoot such scenes was whether to employ large numbers of real humans, all of whom would need to be directed, fed, and so on, or to try to animate these scenes with top-down control.
#
# The company *Massive* realized that ABM could cut this Gordian knot: instead of trying to control all of the animation top down, film makers could instead create "agents" who would follow simple rules, and then instantiate a whole host of such agents, and create the movie episode by simple allowing all of those agents to follow their own rules.
#
# This technique was so successful in the *Lord of the Rings* movies that since then [most film makers](http://www.massivesoftware.com/gallery.html) desiring huge crowd scenes have used ABM.

# %%
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/EmTz7EAYLrs" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')

# %% [markdown]
# ### Our ABM Efforts

# %% [markdown]
# Let's look at a few agent based models we've made here at Tandon.
#
# The first one is of the spread of a forestfire.

# %%
# %matplotlib inline
from models.forest_fire import main as ffmain

ffmain()
# Out:
# Creating new registry
# What is the grid height? [2-100] (40)
# What is the grid width? [2-100] (40)
# What is the probability a tree will catch fire on its own? [0.0001-0.5] (0.01)
# How dense are the trees in the forest? [0.1-0.8] (0.44)
# Creating new registry with key: 59922976
# Welcome to Indra, terminal!
# Running model forest_fire
#
# ***************
# Menu of Actions
# ***************
# 1.  Run for N periods
# 2.  Display a population graph
# 3.  Display a scatter plot
# 4.  Display a bar graph
# 5.  Examine model data
# 7.  View log
# 0.  Quit
# Please choose a number from the menu above:
# 3
# ***************
# Menu of Actions
# ***************
# 1.  Run for N periods
# 2.  Display a population graph
# 3.  Display a scatter plot
# 4.  Display a bar graph
# 5.  Examine model data
# 7.  View log
# 0.  Quit
# Please choose a number from the menu above:
#
# How many periods?
# In user, calling model to run 1 steps.
#
# ==================
# Census for period 0
# ==================
# Group census:
# ==================
#   Healthy (members: 704)
#   New Fire (members: 0)
#   On Fire (members: 0)
#   Burned Out (members: 0)
#   New Growth (members: 0)
# ==================
#  Agent census:
# ==================
#   Agents who moved: 0
#   Agents who switched groups: 0
#
# ***************
# Menu of Actions
# ***************
# 1.  Run for N periods
# 2.  Display a population graph
# 3.  Display a scatter plot
# 4.  Display a bar graph
# 5.  Examine model data
# 7.  View log
# 0.  Quit
# Please choose a number from the menu above:
#
# How many periods?
# In user, calling model to run 1 steps.
#
# ==================
# Census for period 1
# ==================
# Group census:
# ==================
#   Healthy (members: 699)
#   New Fire (members: 5)
#   On Fire (members: 0)
#   Burned Out (members: 0)
#   New Growth (members: 0)
# ==================
#  Agent census:
# ==================
#   Agents who moved: 0
#   Agents who switched groups: 5
#
# ***************
# Menu of Actions
# ***************
# 1.  Run for N periods
# 2.  Display a population graph
# 3.  Display a scatter plot
# 4.  Display a bar graph
# 5.  Examine model data
# 7.  View log
# 0.  Quit
# Please choose a number from the menu above:
#
# How many periods?
# In user, calling model to run 1 steps.
#
# ==================
# Census for period 2
# ==================
# Group census:
# ==================
#   Healthy (members: 693)
#   New Fire (members: 6)
#   On Fire (members: 5)
#   Burned Out (members: 0)
#   New Growth (members: 0)
# ==================
#  Agent census:
# ==================
#   Agents who moved: 0
#   Agents who switched groups: 11
#
# ***************
# Menu of Actions
# ***************
# 1.  Run for N periods
# 2.  Display a population graph
# 3.  Display a scatter plot
# 4.  Display a bar graph
# 5.  Examine model data
# 7.  View log
# 0.  Quit
# Please choose a number from the menu above:
#
# How many periods?
# In user, calling model to run 1 steps.
#
# ==================
# Census for period 3
# ==================
# Group census:
# ==================
#   Healthy (members: 669)
#   New Fire (members: 24)
#   On Fire (members: 6)
#   Burned Out (members: 5)
#   New Growth (members: 0)
# ==================
#  Agent census:
# ==================
#   Agents who moved: 0
#   Agents who switched groups: 35
#
# ***************
# Menu of Actions
# ***************
# 1.  Run for N periods
# 2.  Display a population graph
# 3.  Display a scatter plot
# 4.  Display a bar graph
# 5.  Examine model data
# 7.  View log
# 0.  Quit
# Please choose a number from the menu above:
#
# How many periods?
# In user, calling model to run 1 steps.
#
# ==================
# Census for period 4
# ==================
# Group census:
# ==================
#   Healthy (members: 634)
#   New Fire (members: 35)
#   On Fire (members: 24)
#   Burned Out (members: 11)
#   New Growth (members: 0)
# ==================
#  Agent census:
# ==================
#   Agents who moved: 0
#   Agents who switched groups: 65
#
# ***************
# Menu of Actions
# ***************
# 1.  Run for N periods
# 2.  Display a population graph
# 3.  Display a scatter plot
# 4.  Display a bar graph
# 5.  Examine model data
# 7.  View log
# 0.  Quit
# Please choose a number from the menu above:
#
# How many periods?
# In user, calling model to run 1 steps.
#
# ==================
# Census for period 5
# ==================
# Group census:
# ==================
#   Healthy (members: 592)
#   New Fire (members: 42)
#   On Fire (members: 35)
#   Burned Out (members: 35)
#   New Growth (members: 0)
# ==================
#  Agent census:
# ==================
#   Agents who moved: 0
#   Agents who switched groups: 101
#
# ***************
# Menu of Actions
# ***************
# 1.  Run for N periods
# 2.  Display a population graph
# 3.  Display a scatter plot
# 4.  Display a bar graph
# 5.  Examine model data
# 7.  View log
# 0.  Quit
# Please choose a number from the menu above:
#
# How many periods?
# In user, calling model to run 1 steps.
#
# ==================
# Census for period 6
# ==================
# Group census:
# ==================
#   Healthy (members: 540)
#   New Fire (members: 52)
#   On Fire (members: 42)
#   Burned Out (members: 69)
#   New Growth (members: 1)
# ==================
#  Agent census:
# ==================
#   Agents who moved: 0
#   Agents who switched groups: 130
#
# ***************
# Menu of Actions
# ***************
# 1.  Run for N periods
# 2.  Display a population graph
# 3.  Display a scatter plot
# 4.  Display a bar graph
# 5.  Examine model data
# 7.  View log
# 0.  Quit
# Please choose a number from the menu above:
#
# How many periods?
# In user, calling model to run 1 steps.
#
# ==================
# Census for period 7
# ==================
# Group census:
# ==================
#   Healthy (members: 477)
#   New Fire (members: 64)
#   On Fire (members: 52)
#   Burned Out (members: 110)
#   New Growth (members: 1)
# ==================
#  Agent census:
# ==================
#   Agents who moved: 0
#   Agents who switched groups: 160
#
# ***************
# Menu of Actions
# ***************
# 1.  Run for N periods
# 2.  Display a population graph
# 3.  Display a scatter plot
# 4.  Display a bar graph
# 5.  Examine model data
# 7.  View log
# 0.  Quit
# Please choose a number from the menu above:
#
# How many periods?
# In user, calling model to run 1 steps.
#
# ==================
# Census for period 8
# ==================
# Group census:
# ==================
#   Healthy (members: 406)
#   New Fire (members: 72)
#   On Fire (members: 64)
#   Burned Out (members: 160)
#   New Growth (members: 2)
# ==================
#  Agent census:
# ==================
#   Agents who moved: 0
#   Agents who switched groups: 191
#
# ***************
# Menu of Actions
# ***************
# 1.  Run for N periods
# 2.  Display a population graph
# 3.  Display a scatter plot
# 4.  Display a bar graph
# 5.  Examine model data
# 7.  View log
# 0.  Quit
# Please choose a number from the menu above:
#
# How many periods?
# In user, calling model to run 1 steps.
#
# ==================
# Census for period 9
# ==================
# Group census:
# ==================
#   Healthy (members: 335)
#   New Fire (members: 73)
#   On Fire (members: 72)
#   Burned Out (members: 222)
#   New Growth (members: 2)
# ==================
#  Agent census:
# ==================
#   Agents who moved: 0
#   Agents who switched groups: 213
#
# ***************
# Menu of Actions
# ***************
# 1.  Run for N periods
# 2.  Display a population graph
# 3.  Display a scatter plot
# 4.  Display a bar graph
# 5.  Examine model data
# 7.  View log
# 0.  Quit
# Please choose a number from the menu above:
#
# How many periods?
# In user, calling model to run 1 steps.
#
# ==================
# Census for period 10
# ==================
# Group census:
# ==================
#   Healthy (members: 280)
#   New Fire (members: 57)
#   On Fire (members: 73)
#   Burned Out (members: 294)
#   New Growth (members: 0)
# ==================
#  Agent census:
# ==================
#   Agents who moved: 0
#   Agents who switched groups: 204
#
# ***************
# Menu of Actions
# ***************
# 1.  Run for N periods
# 2.  Display a population graph
# 3.  Display a scatter plot
# 4.  Display a bar graph
# 5.  Examine model data
# 7.  View log
# 0.  Quit
# Please choose a number from the menu above:
#
# How many periods?
# In user, calling model to run 1 steps.
#
# ==================
# Census for period 11
# ==================
# Group census:
# ==================
#   Healthy (members: 228)
#   New Fire (members: 52)
#   On Fire (members: 57)
#   Burned Out (members: 364)
#   New Growth (members: 3)
# ==================
#  Agent census:
# ==================
#   Agents who moved: 0
#   Agents who switched groups: 185
#
# ***************
# Menu of Actions
# ***************
# 1.  Run for N periods
# 2.  Display a population graph
# 3.  Display a scatter plot
# 4.  Display a bar graph
# 5.  Examine model data
# 7.  View log
# 0.  Quit
# Please choose a number from the menu above:
# 0
# Goodbye, terminal, I will miss you!
# 0

# %% [markdown]
# Another model we've built is of panic spreading in a crowd:

# %%
# %matplotlib inline
from models.panic import main as pamain

pamain()
# Out:
# What is the grid height? [2-100] (20)
# What is the grid width? [2-100] (20)
# What is the percentage of agents panicking [0-100] (10)
# Creating new registry with key: 693686520
# Welcome to Indra, terminal!
# Running model panic
#
# ***************
# Menu of Actions
# ***************
# 1.  Run for N periods
# 2.  Display a population graph
# 3.  Display a scatter plot
# 4.  Display a bar graph
# 5.  Examine model data
# 7.  View log
# 0.  Quit
# Please choose a number from the menu above:
# 3
# ***************
# Menu of Actions
# ***************
# 1.  Run for N periods
# 2.  Display a population graph
# 3.  Display a scatter plot
# 4.  Display a bar graph
# 5.  Examine model data
# 7.  View log
# 0.  Quit
# Please choose a number from the menu above:
#
# How many periods?
# In user, calling model to run 1 steps.
#
# ==================
# Census for period 0
# ==================
# Group census:
# ==================
#   Calm (members: 400)
#   Panic (members: 0)
# ==================
#  Agent census:
# ==================
#   Agents who moved: 0
#   Agents who switched groups: 0
# Attempt to del non-existent mbr: Calm179
# Attempt to del non-existent mbr: Calm173
# Attempt to del non-existent mbr: Calm161
# Attempt to del non-existent mbr: Calm17
#
# ***************
# Menu of Actions
# ***************
# 1.  Run for N periods
# 2.  Display a population graph
# 3.  Display a scatter plot
# 4.  Display a bar graph
# 5.  Examine model data
# 7.  View log
# 0.  Quit
# Please choose a number from the menu above:
#
# How many periods?
# In user, calling model to run 1 steps.
#
# ==================
# Census for period 1
# ==================
# Group census:
# ==================
#   Calm (members: 361)
#   Panic (members: 39)
# ==================
#  Agent census:
# ==================
#   Agents who moved: 0
#   Agents who switched groups: 43
#
# ***************
# Menu of Actions
# ***************
# 1.  Run for N periods
# 2.  Display a population graph
# 3.  Display a scatter plot
# 4.  Display a bar graph
# 5.  Examine model data
# 7.  View log
# 0.  Quit
# Please choose a number from the menu above:
#
# How many periods?
# In user, calling model to run 1 steps.
#
# ==================
# Census for period 2
# ==================
# Group census:
# ==================
#   Calm (members: 332)
#   Panic (members: 68)
# ==================
#  Agent census:
# ==================
#   Agents who moved: 0
#   Agents who switched groups: 29
#
# ***************
# Menu of Actions
# ***************
# 1.  Run for N periods
# 2.  Display a population graph
# 3.  Display a scatter plot
# 4.  Display a bar graph
# 5.  Examine model data
# 7.  View log
# 0.  Quit
# Please choose a number from the menu above:
#
# How many periods?
# In user, calling model to run 1 steps.
#
# ==================
# Census for period 3
# ==================
# Group census:
# ==================
#   Calm (members: 299)
#   Panic (members: 101)
# ==================
#  Agent census:
# ==================
#   Agents who moved: 0
#   Agents who switched groups: 33
#
# ***************
# Menu of Actions
# ***************
# 1.  Run for N periods
# 2.  Display a population graph
# 3.  Display a scatter plot
# 4.  Display a bar graph
# 5.  Examine model data
# 7.  View log
# 0.  Quit
# Please choose a number from the menu above:
#
# How many periods?
# In user, calling model to run 1 steps.
#
# ==================
# Census for period 4
# ==================
# Group census:
# ==================
#   Calm (members: 261)
#   Panic (members: 139)
# ==================
#  Agent census:
# ==================
#   Agents who moved: 0
#   Agents who switched groups: 38
#
# ***************
# Menu of Actions
# ***************
# 1.  Run for N periods
# 2.  Display a population graph
# 3.  Display a scatter plot
# 4.  Display a bar graph
# 5.  Examine model data
# 7.  View log
# 0.  Quit
# Please choose a number from the menu above:
#
# How many periods?
# In user, calling model to run 1 steps.
#
# ==================
# Census for period 5
# ==================
# Group census:
# ==================
#   Calm (members: 231)
#   Panic (members: 169)
# ==================
#  Agent census:
# ==================
#   Agents who moved: 0
#   Agents who switched groups: 30
#
# ***************
# Menu of Actions
# ***************
# 1.  Run for N periods
# 2.  Display a population graph
# 3.  Display a scatter plot
# 4.  Display a bar graph
# 5.  Examine model data
# 7.  View log
# 0.  Quit
# Please choose a number from the menu above:
#
# How many periods?
# In user, calling model to run 1 steps.
#
# ==================
# Census for period 6
# ==================
# Group census:
# ==================
#   Calm (members: 214)
#   Panic (members: 186)
# ==================
#  Agent census:
# ==================
#   Agents who moved: 0
#   Agents who switched groups: 17
#
# ***************
# Menu of Actions
# ***************
# 1.  Run for N periods
# 2.  Display a population graph
# 3.  Display a scatter plot
# 4.  Display a bar graph
# 5.  Examine model data
# 7.  View log
# 0.  Quit
# Please choose a number from the menu above:
# 0
# Goodbye, terminal, I will miss you!
# 0

# %% [markdown]
# Finally, let's look at the model of the emergence of money developed by economist Carl Menger, which suggested the money is an *emergent* phenomenon.

# %%
# %matplotlib inline
from capital.money import main as momain

momain()
# Out:
# How many traders do you want? [2-8] (8)
# Do you want to consider divisibility? (1/0 Yes/No) [0-1] (1)
# Do you want to consider durability? (1/0 Yes/No) [0-1] (1)
# Do you want to consider transportability? (1/0 Yes/No) [0-1] (0)
# Creating new registry with key: 804104759
# Welcome to Indra, terminal!
# {
#     "name": "traders0",
#     "type": "Agent",
#     "duration": 9223372036854775807,
#     "pos": null,
#     "attrs": {
#         "goods": {
#             "cow": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 0.8,
#                 "divisibility": 1.0,
#                 "trade_count": 0,
#                 "is_allocated": false,
#                 "age": 1
#             },
#             "cheese": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 0.5,
#                 "divisibility": 0.4,
#                 "trade_count": 0,
#                 "is_allocated": false,
#                 "age": 1
#             },
#             "gold": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 1.0,
#                 "divisibility": 0.05,
#                 "trade_count": 0,
#                 "is_allocated": false,
#                 "age": 1
#             },
#             "banana": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 0.2,
#                 "divisibility": 0.2,
#                 "trade_count": 0,
#                 "is_allocated": false,
#                 "age": 1
#             },
#             "diamond": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 1.0,
#                 "divisibility": 0.8,
#                 "trade_count": 0,
#                 "is_allocated": false,
#                 "age": 1
#             },
#             "avocado": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 0.3,
#                 "divisibility": 0.5,
#                 "trade_count": 0,
#                 "is_allocated": false,
#                 "age": 1,
#                 "color": "green"
#             },
#             "stone": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 1.0,
#                 "divisibility": 1.0,
#                 "trade_count": 0,
#                 "is_allocated": false,
#                 "age": 1
#             },
#             "milk": {
#                 "amt_available": 100,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 0.2,
#                 "divisibility": 0.15,
#                 "trade_count": 0,
#                 "is_allocated": false,
#                 "age": 1
#             }
#         },
#         "util": 0,
#         "pre_trade_util": 0
#     },
#     "active": true,
#     "prim_group": "traders",
#     "neighbors": null,
#     "action": "/Users/gcallah/GitProjects/IndraABM/registry/db/804104759-traders0-trader_action.pkl",
#     "exec_key": 804104759
# }
# {
#     "name": "traders1",
#     "type": "Agent",
#     "duration": 9223372036854775807,
#     "pos": null,
#     "attrs": {
#         "goods": {
#             "cow": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 0.8,
#                 "divisibility": 1.0,
#                 "trade_count": 0,
#                 "is_allocated": false,
#                 "age": 1
#             },
#             "cheese": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 0.5,
#                 "divisibility": 0.4,
#                 "trade_count": 0,
#                 "is_allocated": false,
#                 "age": 1
#             },
#             "gold": {
#                 "amt_available": 100,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 1.0,
#                 "divisibility": 0.05,
#                 "trade_count": 0,
#                 "is_allocated": false,
#                 "age": 1
#             },
#             "banana": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 0.2,
#                 "divisibility": 0.2,
#                 "trade_count": 0,
#                 "is_allocated": false,
#                 "age": 1
#             },
#             "diamond": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 1.0,
#                 "divisibility": 0.8,
#                 "trade_count": 0,
#                 "is_allocated": false,
#                 "age": 1
#             },
#             "avocado": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 0.3,
#                 "divisibility": 0.5,
#                 "trade_count": 0,
#                 "is_allocated": false,
#                 "age": 1,
#                 "color": "green"
#             },
#             "stone": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 1.0,
#                 "divisibility": 1.0,
#                 "trade_count": 0,
#                 "is_allocated": false,
#                 "age": 1
#             },
#             "milk": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 0.2,
#                 "divisibility": 0.15,
#                 "trade_count": 0,
#                 "is_allocated": true,
#                 "age": 1
#             }
#         },
#         "util": 0,
#         "pre_trade_util": 0
#     },
#     "active": true,
#     "prim_group": "traders",
#     "neighbors": null,
#     "action": "/Users/gcallah/GitProjects/IndraABM/registry/db/804104759-traders0-trader_action.pkl",
#     "exec_key": 804104759
# }
# {
#     "name": "traders2",
#     "type": "Agent",
#     "duration": 9223372036854775807,
#     "pos": null,
#     "attrs": {
#         "goods": {
#             "cow": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 0.8,
#                 "divisibility": 1.0,
#                 "trade_count": 0,
#                 "is_allocated": false,
#                 "age": 1
#             },
#             "cheese": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 0.5,
#                 "divisibility": 0.4,
#                 "trade_count": 0,
#                 "is_allocated": false,
#                 "age": 1
#             },
#             "gold": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 1.0,
#                 "divisibility": 0.05,
#                 "trade_count": 0,
#                 "is_allocated": true,
#                 "age": 1
#             },
#             "banana": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 0.2,
#                 "divisibility": 0.2,
#                 "trade_count": 0,
#                 "is_allocated": false,
#                 "age": 1
#             },
#             "diamond": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 1.0,
#                 "divisibility": 0.8,
#                 "trade_count": 0,
#                 "is_allocated": false,
#                 "age": 1
#             },
#             "avocado": {
#                 "amt_available": 100,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 0.3,
#                 "divisibility": 0.5,
#                 "trade_count": 0,
#                 "is_allocated": false,
#                 "age": 1,
#                 "color": "green"
#             },
#             "stone": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 1.0,
#                 "divisibility": 1.0,
#                 "trade_count": 0,
#                 "is_allocated": false,
#                 "age": 1
#             },
#             "milk": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 0.2,
#                 "divisibility": 0.15,
#                 "trade_count": 0,
#                 "is_allocated": true,
#                 "age": 1
#             }
#         },
#         "util": 0,
#         "pre_trade_util": 0
#     },
#     "active": true,
#     "prim_group": "traders",
#     "neighbors": null,
#     "action": "/Users/gcallah/GitProjects/IndraABM/registry/db/804104759-traders0-trader_action.pkl",
#     "exec_key": 804104759
# }
# {
#     "name": "traders3",
#     "type": "Agent",
#     "duration": 9223372036854775807,
#     "pos": null,
#     "attrs": {
#         "goods": {
#             "cow": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 0.8,
#                 "divisibility": 1.0,
#                 "trade_count": 0,
#                 "is_allocated": false,
#                 "age": 1
#             },
#             "cheese": {
#                 "amt_available": 100,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 0.5,
#                 "divisibility": 0.4,
#                 "trade_count": 0,
#                 "is_allocated": false,
#                 "age": 1
#             },
#             "gold": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 1.0,
#                 "divisibility": 0.05,
#                 "trade_count": 0,
#                 "is_allocated": true,
#                 "age": 1
#             },
#             "banana": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 0.2,
#                 "divisibility": 0.2,
#                 "trade_count": 0,
#                 "is_allocated": false,
#                 "age": 1
#             },
#             "diamond": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 1.0,
#                 "divisibility": 0.8,
#                 "trade_count": 0,
#                 "is_allocated": false,
#                 "age": 1
#             },
#             "avocado": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 0.3,
#                 "divisibility": 0.5,
#                 "trade_count": 0,
#                 "is_allocated": true,
#                 "age": 1,
#                 "color": "green"
#             },
#             "stone": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 1.0,
#                 "divisibility": 1.0,
#                 "trade_count": 0,
#                 "is_allocated": false,
#                 "age": 1
#             },
#             "milk": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 0.2,
#                 "divisibility": 0.15,
#                 "trade_count": 0,
#                 "is_allocated": true,
#                 "age": 1
#             }
#         },
#         "util": 0,
#         "pre_trade_util": 0
#     },
#     "active": true,
#     "prim_group": "traders",
#     "neighbors": null,
#     "action": "/Users/gcallah/GitProjects/IndraABM/registry/db/804104759-traders0-trader_action.pkl",
#     "exec_key": 804104759
# }
# {
#     "name": "traders4",
#     "type": "Agent",
#     "duration": 9223372036854775807,
#     "pos": null,
#     "attrs": {
#         "goods": {
#             "cow": {
#                 "amt_available": 100,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 0.8,
#                 "divisibility": 1.0,
#                 "trade_count": 0,
#                 "is_allocated": false,
#                 "age": 1
#             },
#             "cheese": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 0.5,
#                 "divisibility": 0.4,
#                 "trade_count": 0,
#                 "is_allocated": true,
#                 "age": 1
#             },
#             "gold": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 1.0,
#                 "divisibility": 0.05,
#                 "trade_count": 0,
#                 "is_allocated": true,
#                 "age": 1
#             },
#             "banana": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 0.2,
#                 "divisibility": 0.2,
#                 "trade_count": 0,
#                 "is_allocated": false,
#                 "age": 1
#             },
#             "diamond": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 1.0,
#                 "divisibility": 0.8,
#                 "trade_count": 0,
#                 "is_allocated": false,
#                 "age": 1
#             },
#             "avocado": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 0.3,
#                 "divisibility": 0.5,
#                 "trade_count": 0,
#                 "is_allocated": true,
#                 "age": 1,
#                 "color": "green"
#             },
#             "stone": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 1.0,
#                 "divisibility": 1.0,
#                 "trade_count": 0,
#                 "is_allocated": false,
#                 "age": 1
#             },
#             "milk": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 0.2,
#                 "divisibility": 0.15,
#                 "trade_count": 0,
#                 "is_allocated": true,
#                 "age": 1
#             }
#         },
#         "util": 0,
#         "pre_trade_util": 0
#     },
#     "active": true,
#     "prim_group": "traders",
#     "neighbors": null,
#     "action": "/Users/gcallah/GitProjects/IndraABM/registry/db/804104759-traders0-trader_action.pkl",
#     "exec_key": 804104759
# }
# {
#     "name": "traders5",
#     "type": "Agent",
#     "duration": 9223372036854775807,
#     "pos": null,
#     "attrs": {
#         "goods": {
#             "cow": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 0.8,
#                 "divisibility": 1.0,
#                 "trade_count": 0,
#                 "is_allocated": true,
#                 "age": 1
#             },
#             "cheese": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 0.5,
#                 "divisibility": 0.4,
#                 "trade_count": 0,
#                 "is_allocated": true,
#                 "age": 1
#             },
#             "gold": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 1.0,
#                 "divisibility": 0.05,
#                 "trade_count": 0,
#                 "is_allocated": true,
#                 "age": 1
#             },
#             "banana": {
#                 "amt_available": 100,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 0.2,
#                 "divisibility": 0.2,
#                 "trade_count": 0,
#                 "is_allocated": false,
#                 "age": 1
#             },
#             "diamond": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 1.0,
#                 "divisibility": 0.8,
#                 "trade_count": 0,
#                 "is_allocated": false,
#                 "age": 1
#             },
#             "avocado": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 0.3,
#                 "divisibility": 0.5,
#                 "trade_count": 0,
#                 "is_allocated": true,
#                 "age": 1,
#                 "color": "green"
#             },
#             "stone": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 1.0,
#                 "divisibility": 1.0,
#                 "trade_count": 0,
#                 "is_allocated": false,
#                 "age": 1
#             },
#             "milk": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 0.2,
#                 "divisibility": 0.15,
#                 "trade_count": 0,
#                 "is_allocated": true,
#                 "age": 1
#             }
#         },
#         "util": 0,
#         "pre_trade_util": 0
#     },
#     "active": true,
#     "prim_group": "traders",
#     "neighbors": null,
#     "action": "/Users/gcallah/GitProjects/IndraABM/registry/db/804104759-traders0-trader_action.pkl",
#     "exec_key": 804104759
# }
# {
#     "name": "traders6",
#     "type": "Agent",
#     "duration": 9223372036854775807,
#     "pos": null,
#     "attrs": {
#         "goods": {
#             "cow": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 0.8,
#                 "divisibility": 1.0,
#                 "trade_count": 0,
#                 "is_allocated": true,
#                 "age": 1
#             },
#             "cheese": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 0.5,
#                 "divisibility": 0.4,
#                 "trade_count": 0,
#                 "is_allocated": true,
#                 "age": 1
#             },
#             "gold": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 1.0,
#                 "divisibility": 0.05,
#                 "trade_count": 0,
#                 "is_allocated": true,
#                 "age": 1
#             },
#             "banana": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 0.2,
#                 "divisibility": 0.2,
#                 "trade_count": 0,
#                 "is_allocated": true,
#                 "age": 1
#             },
#             "diamond": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 1.0,
#                 "divisibility": 0.8,
#                 "trade_count": 0,
#                 "is_allocated": false,
#                 "age": 1
#             },
#             "avocado": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 0.3,
#                 "divisibility": 0.5,
#                 "trade_count": 0,
#                 "is_allocated": true,
#                 "age": 1,
#                 "color": "green"
#             },
#             "stone": {
#                 "amt_available": 100,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 1.0,
#                 "divisibility": 1.0,
#                 "trade_count": 0,
#                 "is_allocated": false,
#                 "age": 1
#             },
#             "milk": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 0.2,
#                 "divisibility": 0.15,
#                 "trade_count": 0,
#                 "is_allocated": true,
#                 "age": 1
#             }
#         },
#         "util": 0,
#         "pre_trade_util": 0
#     },
#     "active": true,
#     "prim_group": "traders",
#     "neighbors": null,
#     "action": "/Users/gcallah/GitProjects/IndraABM/registry/db/804104759-traders0-trader_action.pkl",
#     "exec_key": 804104759
# }
# {
#     "name": "traders7",
#     "type": "Agent",
#     "duration": 9223372036854775807,
#     "pos": null,
#     "attrs": {
#         "goods": {
#             "cow": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 0.8,
#                 "divisibility": 1.0,
#                 "trade_count": 0,
#                 "is_allocated": true,
#                 "age": 1
#             },
#             "cheese": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 0.5,
#                 "divisibility": 0.4,
#                 "trade_count": 0,
#                 "is_allocated": true,
#                 "age": 1
#             },
#             "gold": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 1.0,
#                 "divisibility": 0.05,
#                 "trade_count": 0,
#                 "is_allocated": true,
#                 "age": 1
#             },
#             "banana": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 0.2,
#                 "divisibility": 0.2,
#                 "trade_count": 0,
#                 "is_allocated": true,
#                 "age": 1
#             },
#             "diamond": {
#                 "amt_available": 100,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 1.0,
#                 "divisibility": 0.8,
#                 "trade_count": 0,
#                 "is_allocated": false,
#                 "age": 1
#             },
#             "avocado": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 0.3,
#                 "divisibility": 0.5,
#                 "trade_count": 0,
#                 "is_allocated": true,
#                 "age": 1,
#                 "color": "green"
#             },
#             "stone": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 1.0,
#                 "divisibility": 1.0,
#                 "trade_count": 0,
#                 "is_allocated": true,
#                 "age": 1
#             },
#             "milk": {
#                 "amt_available": 0,
#                 "util_func": "gen_util_func",
#                 "incr": 0,
#                 "durability": 0.2,
#                 "divisibility": 0.15,
#                 "trade_count": 0,
#                 "is_allocated": true,
#                 "age": 1
#             }
#         },
#         "util": 0,
#         "pre_trade_util": 0
#     },
#     "active": true,
#     "prim_group": "traders",
#     "neighbors": null,
#     "action": "/Users/gcallah/GitProjects/IndraABM/registry/db/804104759-traders0-trader_action.pkl",
#     "exec_key": 804104759
# }
# Running model money
#
# ***************
# Menu of Actions
# ***************
# 1.  Run for N periods
# 2.  Display a population graph
# 3.  Display a scatter plot
# 4.  Display a bar graph
# 5.  Examine model data
# 7.  View log
# 0.  Quit
# Please choose a number from the menu above:
# How many periods? 40
# Steps = 40
# In user, calling model to run 40 steps.
# Number of trades last period:
# {'cow': 1, 'cheese': 3, 'gold': 1, 'banana': 2, 'diamond': 2, 'avocado': 2, 'stone': 1, 'milk': 4}
#
# Number of trades last period:
# {'cow': 4, 'cheese': 3, 'gold': 4, 'banana': 4, 'diamond': 3, 'avocado': 5, 'stone': 3, 'milk': 6}
#
# Number of trades last period:
# {'cow': 7, 'cheese': 7, 'gold': 5, 'banana': 8, 'diamond': 4, 'avocado': 5, 'stone': 4, 'milk': 8}
#
# Number of trades last period:
# {'cow': 9, 'cheese': 8, 'gold': 7, 'banana': 9, 'diamond': 6, 'avocado': 7, 'stone': 6, 'milk': 12}
#
# Number of trades last period:
# {'cow': 11, 'cheese': 12, 'gold': 7, 'banana': 11, 'diamond': 9, 'avocado': 8, 'stone': 7, 'milk': 15}
#
# Number of trades last period:
# {'cow': 13, 'cheese': 15, 'gold': 10, 'banana': 13, 'diamond': 10, 'avocado': 10, 'stone': 8, 'milk': 17}
#
# Number of trades last period:
# {'cow': 14, 'cheese': 16, 'gold': 14, 'banana': 17, 'diamond': 12, 'avocado': 11, 'stone': 10, 'milk': 18}
#
# Number of trades last period:
# {'cow': 16, 'cheese': 18, 'gold': 18, 'banana': 19, 'diamond': 12, 'avocado': 13, 'stone': 11, 'milk': 21}
#
# Number of trades last period:
# {'cow': 19, 'cheese': 18, 'gold': 22, 'banana': 23, 'diamond': 14, 'avocado': 14, 'stone': 11, 'milk': 23}
#
# Number of trades last period:
# {'cow': 21, 'cheese': 18, 'gold': 24, 'banana': 27, 'diamond': 15, 'avocado': 17, 'stone': 13, 'milk': 25}
#
# Number of trades last period:
# {'cow': 23, 'cheese': 19, 'gold': 26, 'banana': 31, 'diamond': 16, 'avocado': 20, 'stone': 14, 'milk': 27}
#
# Number of trades last period:
# {'cow': 25, 'cheese': 21, 'gold': 29, 'banana': 32, 'diamond': 19, 'avocado': 21, 'stone': 16, 'milk': 29}
#
# Number of trades last period:
# {'cow': 28, 'cheese': 23, 'gold': 31, 'banana': 33, 'diamond': 21, 'avocado': 25, 'stone': 16, 'milk': 31}
#
# Number of trades last period:
# {'cow': 29, 'cheese': 25, 'gold': 33, 'banana': 37, 'diamond': 22, 'avocado': 27, 'stone': 17, 'milk': 34}
#
# Number of trades last period:
# {'cow': 31, 'cheese': 27, 'gold': 35, 'banana': 39, 'diamond': 24, 'avocado': 31, 'stone': 17, 'milk': 36}
#
# Number of trades last period:
# {'cow': 31, 'cheese': 31, 'gold': 37, 'banana': 41, 'diamond': 26, 'avocado': 33, 'stone': 18, 'milk': 39}
#
# Number of trades last period:
# {'cow': 32, 'cheese': 32, 'gold': 39, 'banana': 42, 'diamond': 28, 'avocado': 35, 'stone': 19, 'milk': 43}
#
# Number of trades last period:
# {'cow': 32, 'cheese': 34, 'gold': 44, 'banana': 45, 'diamond': 29, 'avocado': 38, 'stone': 19, 'milk': 45}
#
# Number of trades last period:
# {'cow': 33, 'cheese': 38, 'gold': 47, 'banana': 49, 'diamond': 29, 'avocado': 39, 'stone': 20, 'milk': 47}
#
# Number of trades last period:
# {'cow': 34, 'cheese': 40, 'gold': 48, 'banana': 51, 'diamond': 31, 'avocado': 41, 'stone': 21, 'milk': 48}
#
# Number of trades last period:
# {'cow': 36, 'cheese': 41, 'gold': 49, 'banana': 55, 'diamond': 33, 'avocado': 44, 'stone': 21, 'milk': 51}
#
# Number of trades last period:
# {'cow': 37, 'cheese': 42, 'gold': 51, 'banana': 57, 'diamond': 33, 'avocado': 47, 'stone': 23, 'milk': 52}
#
# Number of trades last period:
# {'cow': 37, 'cheese': 43, 'gold': 55, 'banana': 59, 'diamond': 35, 'avocado': 49, 'stone': 23, 'milk': 53}
#
# Number of trades last period:
# {'cow': 38, 'cheese': 45, 'gold': 57, 'banana': 60, 'diamond': 36, 'avocado': 50, 'stone': 25, 'milk': 59}
#
# Number of trades last period:
# {'cow': 39, 'cheese': 46, 'gold': 59, 'banana': 62, 'diamond': 37, 'avocado': 52, 'stone': 28, 'milk': 63}
#
# Number of trades last period:
# {'cow': 40, 'cheese': 48, 'gold': 61, 'banana': 64, 'diamond': 37, 'avocado': 53, 'stone': 28, 'milk': 67}
#
# Number of trades last period:
# {'cow': 42, 'cheese': 51, 'gold': 64, 'banana': 65, 'diamond': 39, 'avocado': 55, 'stone': 30, 'milk': 68}
#
# Number of trades last period:
# {'cow': 43, 'cheese': 53, 'gold': 67, 'banana': 68, 'diamond': 41, 'avocado': 58, 'stone': 31, 'milk': 69}
#
# Number of trades last period:
# {'cow': 45, 'cheese': 57, 'gold': 68, 'banana': 71, 'diamond': 42, 'avocado': 60, 'stone': 33, 'milk': 70}
#
# Number of trades last period:
# {'cow': 46, 'cheese': 58, 'gold': 71, 'banana': 73, 'diamond': 43, 'avocado': 63, 'stone': 34, 'milk': 72}
#
# Number of trades last period:
# {'cow': 47, 'cheese': 60, 'gold': 72, 'banana': 75, 'diamond': 45, 'avocado': 67, 'stone': 35, 'milk': 75}
#
# Number of trades last period:
# {'cow': 48, 'cheese': 61, 'gold': 74, 'banana': 75, 'diamond': 47, 'avocado': 68, 'stone': 36, 'milk': 79}
#
# Number of trades last period:
# {'cow': 49, 'cheese': 63, 'gold': 77, 'banana': 78, 'diamond': 48, 'avocado': 69, 'stone': 40, 'milk': 80}
#
# Number of trades last period:
# {'cow': 52, 'cheese': 65, 'gold': 80, 'banana': 79, 'diamond': 48, 'avocado': 72, 'stone': 40, 'milk': 84}
#
# Number of trades last period:
# {'cow': 52, 'cheese': 67, 'gold': 81, 'banana': 82, 'diamond': 50, 'avocado': 73, 'stone': 42, 'milk': 87}
#
# Number of trades last period:
# {'cow': 54, 'cheese': 71, 'gold': 83, 'banana': 84, 'diamond': 53, 'avocado': 75, 'stone': 42, 'milk': 88}
#
# Number of trades last period:
# {'cow': 56, 'cheese': 72, 'gold': 84, 'banana': 87, 'diamond': 54, 'avocado': 76, 'stone': 44, 'milk': 91}
#
# Number of trades last period:
# {'cow': 58, 'cheese': 76, 'gold': 87, 'banana': 88, 'diamond': 58, 'avocado': 76, 'stone': 45, 'milk': 92}
#
# Number of trades last period:
# {'cow': 60, 'cheese': 77, 'gold': 91, 'banana': 91, 'diamond': 60, 'avocado': 76, 'stone': 47, 'milk': 94}
#
# Number of trades last period:
# {'cow': 63, 'cheese': 78, 'gold': 94, 'banana': 92, 'diamond': 61, 'avocado': 76, 'stone': 48, 'milk': 96}
#
#
# ***************
# Menu of Actions
# ***************
# 1.  Run for N periods
# 2.  Display a population graph
# 3.  Display a scatter plot
# 4.  Display a bar graph
# 5.  Examine model data
# 7.  View log
# 0.  Quit
# Please choose a number from the menu above:
# 2
# ***************
# Menu of Actions
# ***************
# 1.  Run for N periods
# 2.  Display a population graph
# 3.  Display a scatter plot
# 4.  Display a bar graph
# 5.  Examine model data
# 7.  View log
# 0.  Quit
# Please choose a number from the menu above:

# %% [markdown]
# ## What Do We Learn from Such Models?
#
# 1. Can we hypothesize a realistic mechanism that produces behavior X?
# 2. If so, how does changing the parameters infuencing X change the outcome?
